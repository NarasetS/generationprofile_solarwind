# %%
import cdsapi
import atlite

# %%
# c = cdsapi.Client()

# c.retrieve(
#     'reanalysis-era5-land',
#     {
#         'variable': [
#             '2m_temperature', 'surface_net_solar_radiation',
#         ],
#         'year': '2022',
#         'month': '01',
#         'day': '01',
#         'time': [
#             '00:00', '01:00', '02:00',
#             '03:00', '04:00', '05:00',
#             '06:00', '07:00', '08:00',
#             '09:00', '10:00', '11:00',
#             '12:00', '13:00', '14:00',
#             '15:00', '16:00', '17:00',
#             '18:00', '19:00', '20:00',
#             '21:00', '22:00', '23:00',
#         ],
#         'area': [
#             90, -180, -90,
#             180,
#         ],
#         'format': 'netcdf',
#     },
#     'download.nc')

# %%
# cutout = atlite.Cutout(
#     path="download.nc",
#     module="era5",
#     x=slice(-13.6913, -10.7712),
#     y=slice(49.9096, 52.8479),
#     dx = 0.05,
#     dy = 0.05,
#     time="2022-01-01",
# )

# cutout.prepare()

# cutout.data

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
import geopandas as gpd
import pandas as pd
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

import cartopy.crs as ccrs
from cartopy.crs import PlateCarree as plate
import cartopy.io.shapereader as shpreader

import xarray as xr
import atlite

import logging
import warnings

warnings.simplefilter("ignore")
logging.captureWarnings(False)
logging.basicConfig(level=logging.INFO)

# %%
# import cdsapi

# dataset = "reanalysis-era5-land"
# request = {
#     'variable': ['surface_net_solar_radiation'],
#     'year': '2015',
#     'month': '01',
#     'day': ['01'],
#     'time': ['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00'],
#     'data_format': 'netcdf',
#     'download_format': 'unarchived',
#     'area': [90, -180, -90, 180]
# }

# client = cdsapi.Client()
# client.retrieve(dataset, request).download()

# %%
shpfilename = shpreader.natural_earth(
    resolution="10m", category="cultural", name="admin_0_countries"
)
reader = shpreader.Reader(shpfilename)
UkIr = gpd.GeoSeries(
    {r.attributes["NAME_EN"]: r.geometry for r in reader.records()},
    crs={"init": "epsg:4326"},
).reindex(["Thailand"])

# %%
UkIr.unary_union.bounds
# Out:
# (97.35140100100011, 5.629890035000059, 105.65099776200003, 20.44500640900013)

# %%
# Define the cutout; this will not yet trigger any major operations
d_input = 0.25
path_input = "th-2011-01-01" + str(d_input)

cutout = atlite.Cutout(
    path=path_input, module="era5", bounds= (97.35140100100011, 10.629890035000059, 98.35140100100011, 11.44500640900013)  , time="2011-01-01", dx= d_input , dy = d_input
)

# This is where all the work happens (this can take some time, for us it took ~15 minutes).
cutout.prepare(['height', 'wind', 'influx', 'temperature'])
# Out:
# INFO:atlite.cutout:Building new cutout th-2011-01-010.nc
# INFO:atlite.data:Storing temporary files in C:\Users\basna\AppData\Local\Temp\tmp724hynxa
# INFO:atlite.data:Calculating and writing with module era5:
# INFO:atlite.datasets.era5:Requesting data for feature wind...
# INFO:atlite.datasets.era5:Requesting data for feature height...
# INFO:atlite.datasets.era5:Requesting data for feature temperature...
# INFO:atlite.datasets.era5:Requesting data for feature influx...
# Done_loadingDone_loading
#
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# 2024-08-29 11:49:57,489 INFO Request ID is d30fcbbe-aa96-40ba-91af-44bc6443e766
# INFO:cads_api_client.processing:Request ID is d30fcbbe-aa96-40ba-91af-44bc6443e766
# 2024-08-29 11:49:57,540 INFO Request ID is 2d5287b7-63ad-4252-8a8e-bfa0cbd29ca0
# INFO:cads_api_client.processing:Request ID is 2d5287b7-63ad-4252-8a8e-bfa0cbd29ca0
# 2024-08-29 11:49:57,550 INFO Request ID is 30cb8877-b4fb-46b0-bacb-8041f16151f6
# INFO:cads_api_client.processing:Request ID is 30cb8877-b4fb-46b0-bacb-8041f16151f6
# 2024-08-29 11:49:57,581 INFO Request ID is d78b4428-dbee-4c88-b3c1-b2458c689652
# INFO:cads_api_client.processing:Request ID is d78b4428-dbee-4c88-b3c1-b2458c689652
# 2024-08-29 11:49:57,798 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-29 11:49:57,851 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-29 11:49:57,873 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-29 11:49:57,884 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-29 11:54:24,774 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-08-29 11:54:24,782 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-08-29 11:54:24,785 INFO status has been updated to successful
# 2024-08-29 11:54:24,791 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	surface_net_solar_radiation (2011-[1])
# 	surface_solar_radiation_downwards (2011-[1])
# 	toa_incident_solar_radiation (2011-[1])
# 	total_sky_direct_solar_radiation_at_surface (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/cc5070b1372492db0e9c907ff53e4e20.nc
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	2m_temperature (2011-[1])
# 	soil_temperature_level_4 (2011-[1])
# 	2m_dewpoint_temperature (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/496753386f45c9a6849ed11941e96548.nc
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	100m_u_component_of_wind (2011-[1])
# 	100m_v_component_of_wind (2011-[1])
# 	forecast_surface_roughness (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/fd3a2f38490a73edc72ad3d73803c8f0.nc
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	geopotential (2011-1)
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/29d1febee11988707adf857fe5fcd996.nc
# <Cutout "th-2011-01-010">
#  x = 97.50 ⟷ 98.25, dx = 0.25
#  y = 10.75 ⟷ 11.25, dy = 0.25
#  time = 2011-01-01 ⟷ 2011-01-01, dt = h
#  module = era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature']

# %%
cutout.data
# Out:
# <xarray.Dataset> Size: 16kB
# Dimensions:               (x: 4, y: 3, time: 24)
# Coordinates:
#   * x                     (x) float64 32B 97.5 97.75 98.0 98.25
#   * y                     (y) float64 24B 10.75 11.0 11.25
#   * time                  (time) datetime64[ns] 192B 2011-01-01 ... 2011-01-0...
#     lon                   (x) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
#     lat                   (y) float64 24B dask.array<chunksize=(3,), meta=np.ndarray>
# Data variables: (12/13)
#     height                (y, x) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
#     wnd100m               (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     wnd_azimuth           (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     roughness             (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     influx_toa            (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     influx_direct         (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     ...                    ...
#     albedo                (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     solar_altitude        (time, y, x) float64 2kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     solar_azimuth         (time, y, x) float64 2kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     temperature           (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     soil temperature      (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
#     dewpoint temperature  (time, y, x) float32 1kB dask.array<chunksize=(24, 3, 4), meta=np.ndarray>
# Attributes:
#     module:                  era5
#     prepared_features:       ['influx', 'height', 'temperature', 'wind']
#     chunksize_time:          100
#     dx:                      0.25
#     dy:                      0.25
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-08-28T09:15 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
cap_factors = cutout.wind(turbine="Vestas_V112_3MW", capacity_factor=True)
# Out:
# INFO:atlite.convert:Convert and aggregate 'wind'.

# %%
cap_factors.plot()
