# %%
import cdsapi
import atlite

# %%
# c = cdsapi.Client()

# c.retrieve(
#     'reanalysis-era5-land',
#     {
#         'variable': [
#             '2m_temperature', 'surface_net_solar_radiation',
#         ],
#         'year': '2022',
#         'month': '01',
#         'day': '01',
#         'time': [
#             '00:00', '01:00', '02:00',
#             '03:00', '04:00', '05:00',
#             '06:00', '07:00', '08:00',
#             '09:00', '10:00', '11:00',
#             '12:00', '13:00', '14:00',
#             '15:00', '16:00', '17:00',
#             '18:00', '19:00', '20:00',
#             '21:00', '22:00', '23:00',
#         ],
#         'area': [
#             90, -180, -90,
#             180,
#         ],
#         'format': 'netcdf',
#     },
#     'download.nc')

# %%
# cutout = atlite.Cutout(
#     path="download.nc",
#     module="era5",
#     x=slice(-13.6913, -10.7712),
#     y=slice(49.9096, 52.8479),
#     dx = 0.05,
#     dy = 0.05,
#     time="2022-01-01",
# )

# cutout.prepare()

# cutout.data

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
import geopandas as gpd
import pandas as pd
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

import cartopy.crs as ccrs
from cartopy.crs import PlateCarree as plate
import cartopy.io.shapereader as shpreader

import xarray as xr
import atlite

import logging
import warnings

warnings.simplefilter("ignore")
logging.captureWarnings(False)
logging.basicConfig(level=logging.INFO)

# %%
# import cdsapi

# dataset = "reanalysis-era5-land"
# request = {
#     'variable': ['surface_net_solar_radiation'],
#     'year': '2015',
#     'month': '01',
#     'day': ['01'],
#     'time': ['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00'],
#     'data_format': 'netcdf',
#     'download_format': 'unarchived',
#     'area': [90, -180, -90, 180]
# }

# client = cdsapi.Client()
# client.retrieve(dataset, request).download()

# %%
shpfilename = shpreader.natural_earth(
    resolution="10m", category="cultural", name="admin_0_countries"
)
reader = shpreader.Reader(shpfilename)
UkIr = gpd.GeoSeries(
    {r.attributes["NAME_EN"]: r.geometry for r in reader.records()},
    crs={"init": "epsg:4326"},
).reindex(["Thailand"])
print(UkIr)
# Out:
# Thailand    MULTIPOLYGON (((102.91358 11.6459, 102.90602 1...
# dtype: geometry

# %%
UkIr.union_all()
# Out:
# <MULTIPOLYGON (((99.086 7.537, 99.101 7.504, 99.117 7.479, 99.1 7.467, 99.07...>

# %%
# Define the cutout; this will not yet trigger any major operations
d_input = 25
path_input = "th_" + str(d_input)

cutout = atlite.Cutout(
    path=path_input, module="era5", 
    bounds= (97.35140100100011, 10.629890035000059, 98.35140100100011, 11.44500640900013)  ,
    time =slice("2010-12-31","2011-01-03"),
    dx = d_input/100 , 
    dy = d_input/100
)

# This is where all the work happens (this can take some time, for us it took ~15 minutes).
cutout.prepare(['height', 'wind', 'influx', 'temperature'])
# Out:
# INFO:atlite.cutout:Building new cutout th_25.nc
# INFO:atlite.data:Storing temporary files in C:\Users\basna\AppData\Local\Temp\tmpocgjz2kf
# INFO:atlite.data:Calculating and writing with module era5:
# INFO:atlite.datasets.era5:Requesting data for feature temperature...
# INFO:atlite.datasets.era5:Requesting data for feature height...
# INFO:atlite.datasets.era5:Requesting data for feature influx...
# INFO:atlite.datasets.era5:Requesting data for feature wind...
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# 2024-09-14 08:41:27,047 INFO Request ID is 16b2dd23-a1b3-459d-8bad-4e8955afad9f
# INFO:cads_api_client.processing:Request ID is 16b2dd23-a1b3-459d-8bad-4e8955afad9f
# 2024-09-14 08:41:27,051 INFO Request ID is b5a4e58f-f2bb-4af7-a05c-62dcf02b56be
# INFO:cads_api_client.processing:Request ID is b5a4e58f-f2bb-4af7-a05c-62dcf02b56be
# 2024-09-14 08:41:27,059 INFO Request ID is edd09662-5d28-42ed-b22e-c82680e23d68
# INFO:cads_api_client.processing:Request ID is edd09662-5d28-42ed-b22e-c82680e23d68
# 2024-09-14 08:41:27,080 INFO Request ID is 5e638ec1-8603-4a20-9f37-4b5c5cc57e6a
# INFO:cads_api_client.processing:Request ID is 5e638ec1-8603-4a20-9f37-4b5c5cc57e6a
# 2024-09-14 08:41:27,354 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-09-14 08:41:27,377 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-09-14 08:41:27,377 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-09-14 08:41:27,388 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-09-14 08:47:49,523 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-09-14 08:47:49,545 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-09-14 08:47:49,548 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-09-14 08:47:49,619 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	2m_temperature (2010-[12])
# 	soil_temperature_level_4 (2010-[12])
# 	2m_dewpoint_temperature (2010-[12])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/c623d028f3b4a808d7ead05303553707.nc
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	geopotential (2010-12)
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/2a47913314a21d1fa5768c712b78c72b.nc
# Done_loading
# Done_loading
# 2a47913314a21d1fa5768c712b78c72b.nc:   0%|          | 0.00/21.3k [00:00<?, ?B/s]2024-09-14 08:47:54,643 INFO Request ID is 2b983f31-a696-483e-bfee-80989967f6ac
# INFO:cads_api_client.processing:Request ID is 2b983f31-a696-483e-bfee-80989967f6ac
# 2024-09-14 08:47:55,024 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	100m_u_component_of_wind (2010-[12])
# 	100m_v_component_of_wind (2010-[12])
# 	forecast_surface_roughness (2010-[12])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/d3a6603df005e564e927c103ef8f39b7.nc
# d3a6603df005e564e927c103ef8f39b7.nc:   0%|          | 0.00/41.1k [00:00<?, ?B/s]2024-09-14 08:47:56,826 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	surface_net_solar_radiation (2010-[12])
# 	surface_solar_radiation_downwards (2010-[12])
# 	toa_incident_solar_radiation (2010-[12])
# 	total_sky_direct_solar_radiation_at_surface (2010-[12])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/7eef84d3d0765172493b5748c01a230.nc
# Done_loading
# Done_loading
# 7eef84d3d0765172493b5748c01a230.nc:   0%|          | 0.00/49.8k [00:00<?, ?B/s]2024-09-14 08:47:59,431 INFO Request ID is fa10b698-851e-4947-8090-4cf265115181
# INFO:cads_api_client.processing:Request ID is fa10b698-851e-4947-8090-4cf265115181
# 2024-09-14 08:47:59,737 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# Done_loading
# Done_loading
# 2024-09-14 08:48:02,029 INFO Request ID is 2a76807d-fa23-4f9f-a066-ecde9f8d95f6
# INFO:cads_api_client.processing:Request ID is 2a76807d-fa23-4f9f-a066-ecde9f8d95f6
# 2024-09-14 08:48:02,337 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-09-14 08:48:03,055 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	2m_temperature (2011-[1])
# 	soil_temperature_level_4 (2011-[1])
# 	2m_dewpoint_temperature (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/b98e2d1164f2037f0a4a4bab432e7263.nc
# 2024-09-14 08:48:04,130 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-09-14 08:48:04,147 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	100m_u_component_of_wind (2011-[1])
# 	100m_v_component_of_wind (2011-[1])
# 	forecast_surface_roughness (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/21a81712e279b84e523aeb0aee9a6ddc.nc
# 2024-09-14 08:48:06,771 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	surface_net_solar_radiation (2011-[1])
# 	surface_solar_radiation_downwards (2011-[1])
# 	toa_incident_solar_radiation (2011-[1])
# 	total_sky_direct_solar_radiation_at_surface (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/4d0d474a2d1f60b6c6652105584132a6.nc
# <Cutout "th_25">
#  x = 97.50 ⟷ 98.25, dx = 0.25
#  y = 10.75 ⟷ 11.25, dy = 0.25
#  time = 2010-12-31 ⟷ 2011-01-03, dt = h
#  module = era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature']

# %%
cutout.data
# Out:
# <xarray.Dataset> Size: 65kB
# Dimensions:               (x: 4, y: 3, time: 96)
# Coordinates:
#   * x                     (x) float64 32B 97.5 97.75 98.0 98.25
#   * y                     (y) float64 24B 10.75 11.0 11.25
#   * time                  (time) datetime64[ns] 768B 2010-12-31 ... 2011-01-0...
#     lon                   (x) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
#     lat                   (y) float64 24B dask.array<chunksize=(3,), meta=np.ndarray>
# Data variables: (12/13)
#     height                (y, x) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
#     wnd100m               (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     wnd_azimuth           (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     roughness             (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     influx_toa            (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     influx_direct         (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     ...                    ...
#     albedo                (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     solar_altitude        (time, y, x) float64 9kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     solar_azimuth         (time, y, x) float64 9kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     temperature           (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     soil temperature      (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
#     dewpoint temperature  (time, y, x) float32 5kB dask.array<chunksize=(96, 3, 4), meta=np.ndarray>
# Attributes:
#     module:                  era5
#     prepared_features:       ['height', 'wind', 'influx', 'temperature']
#     chunksize_time:          100
#     dx:                      0.25
#     dy:                      0.25
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-09-13T06:54 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
cap_factors = cutout.wind(turbine="Vestas_V112_3MW", capacity_factor=True)
# Out:
# INFO:atlite.convert:Convert and aggregate 'wind'.

# %%
cap_factors.plot()

# %%
sites = gpd.GeoDataFrame(
    [
        ["P1", 11, 97.8],
        ["P2", 10.5, 98],
        ["P3", 11.2, 97.5],
    ],
    columns=["name", "y", "x"],
).set_index("name")

cells = cutout.grid
nearest = cutout.data.sel({"x": sites.x.values, "y": sites.y.values}, "nearest").coords
sites["x"] = nearest.get("x").values
sites["y"] = nearest.get("y").values
cells_generation = sites.merge(cells, how="inner").rename(pd.Series(sites.index))
print(cells_generation)

power_generation = cutout.pv(    
        panel="CSi",
        orientation="latitude_optimal",
        capacity_factor=True,
        tracking= None,
        shapes=cells_generation.geometry
)
fig, axes = plt.subplots(len(sites), sharex=True, figsize=(9, 4))


power_generation.to_pandas().plot(subplots=True, ax=axes)
print(power_generation.to_pandas())
fig.tight_layout()
# Out:
# INFO:atlite.convert:Convert and aggregate 'pv'.
#         y      x                                           geometry
# P1  11.00  97.75  POLYGON ((97.875 10.875, 97.875 11.125, 97.625...
# P2  10.75  98.00  POLYGON ((98.125 10.625, 98.125 10.875, 97.875...
# P3  11.25  97.50  POLYGON ((97.625 11.125, 97.625 11.375, 97.375...
# dim_0                      P1        P2        P3
# time
# 2010-12-31 00:00:00  0.000000  0.000000  0.000000
# 2010-12-31 01:00:00  0.076901  0.080539  0.075040
# 2010-12-31 02:00:00  0.267528  0.270238  0.266334
# 2010-12-31 03:00:00  0.436644  0.435613  0.438134
# 2010-12-31 04:00:00  0.570849  0.581508  0.556765
# ...                       ...       ...       ...
# 2011-01-03 19:00:00  0.000000  0.000000  0.000000
# 2011-01-03 20:00:00  0.000000  0.000000  0.000000
# 2011-01-03 21:00:00  0.000000  0.000000  0.000000
# 2011-01-03 22:00:00  0.000000  0.000000  0.000000
# 2011-01-03 23:00:00  0.000000  0.000000  0.000000
#
# [96 rows x 3 columns]

# %%
# area = cells_generation[:1]
area = cells_generation[:1]
print(area)
power_generation = cutout.pv(    
        panel="CSi",
        orientation="latitude_optimal",
        capacity_factor=True,
        tracking= None,
        shapes = area.geometry
)
fig, axes = plt.subplots(len(area), sharex=True, figsize=(9, 4))


power_generation.to_pandas().plot(subplots=True, ax=axes)
fig.tight_layout()
# Out:
# INFO:atlite.convert:Convert and aggregate 'pv'.
#        y      x                                           geometry
# P1  11.0  97.75  POLYGON ((97.875 10.875, 97.875 11.125, 97.625...

# %%
cutout.grid
# Out:
#         x      y                                           geometry
# 0   97.50  10.75  POLYGON ((97.625 10.625, 97.625 10.875, 97.375...
# 1   97.75  10.75  POLYGON ((97.875 10.625, 97.875 10.875, 97.625...
# 2   98.00  10.75  POLYGON ((98.125 10.625, 98.125 10.875, 97.875...
# 3   98.25  10.75  POLYGON ((98.375 10.625, 98.375 10.875, 98.125...
# 4   97.50  11.00  POLYGON ((97.625 10.875, 97.625 11.125, 97.375...
# 5   97.75  11.00  POLYGON ((97.875 10.875, 97.875 11.125, 97.625...
# 6   98.00  11.00  POLYGON ((98.125 10.875, 98.125 11.125, 97.875...
# 7   98.25  11.00  POLYGON ((98.375 10.875, 98.375 11.125, 98.125...
# 8   97.50  11.25  POLYGON ((97.625 11.125, 97.625 11.375, 97.375...
# 9   97.75  11.25  POLYGON ((97.875 11.125, 97.875 11.375, 97.625...
# 10  98.00  11.25  POLYGON ((98.125 11.125, 98.125 11.375, 97.875...
# 11  98.25  11.25  POLYGON ((98.375 11.125, 98.375 11.375, 98.125...
