# %%
import cdsapi
import atlite

# %%
# c = cdsapi.Client()

# c.retrieve(
#     'reanalysis-era5-land',
#     {
#         'variable': [
#             '2m_temperature', 'surface_net_solar_radiation',
#         ],
#         'year': '2022',
#         'month': '01',
#         'day': '01',
#         'time': [
#             '00:00', '01:00', '02:00',
#             '03:00', '04:00', '05:00',
#             '06:00', '07:00', '08:00',
#             '09:00', '10:00', '11:00',
#             '12:00', '13:00', '14:00',
#             '15:00', '16:00', '17:00',
#             '18:00', '19:00', '20:00',
#             '21:00', '22:00', '23:00',
#         ],
#         'area': [
#             90, -180, -90,
#             180,
#         ],
#         'format': 'netcdf',
#     },
#     'download.nc')

# %%
# cutout = atlite.Cutout(
#     path="download.nc",
#     module="era5",
#     x=slice(-13.6913, -10.7712),
#     y=slice(49.9096, 52.8479),
#     dx = 0.05,
#     dy = 0.05,
#     time="2022-01-01",
# )

# cutout.prepare()

# cutout.data

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
import geopandas as gpd
import pandas as pd
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

import cartopy.crs as ccrs
from cartopy.crs import PlateCarree as plate
import cartopy.io.shapereader as shpreader

import xarray as xr
import atlite

import logging
import warnings

warnings.simplefilter("ignore")
logging.captureWarnings(False)
logging.basicConfig(level=logging.INFO)

# %%
# import cdsapi

# dataset = "reanalysis-era5-land"
# request = {
#     'variable': ['surface_net_solar_radiation'],
#     'year': '2015',
#     'month': '01',
#     'day': ['01'],
#     'time': ['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00'],
#     'data_format': 'netcdf',
#     'download_format': 'unarchived',
#     'area': [90, -180, -90, 180]
# }

# client = cdsapi.Client()
# client.retrieve(dataset, request).download()

# %%
shpfilename = shpreader.natural_earth(
    resolution="10m", category="cultural", name="admin_0_countries"
)
reader = shpreader.Reader(shpfilename)
UkIr = gpd.GeoSeries(
    {r.attributes["NAME_EN"]: r.geometry for r in reader.records()},
    crs={"init": "epsg:4326"},
).reindex(["Thailand"])
print(UkIr)
# Out:
# Thailand    MULTIPOLYGON (((102.91358 11.6459, 102.90602 1...
# dtype: geometry

# %%
UkIr.union_all()
# Out:
# <MULTIPOLYGON (((99.086 7.537, 99.101 7.504, 99.117 7.479, 99.1 7.467, 99.07...>

# %%
# Define the cutout; this will not yet trigger any major operations
d_input = 1
path_input = "th_" + str(d_input)

cutout = atlite.Cutout(
    path=path_input, module="era5", 
    bounds= (97.35140100100011, 10.629890035000059, 98.35140100100011, 11.44500640900013)  ,
    time=slice("2011-01-01","2011-01-05"),
    dx= d_input/100 , 
    dy = d_input/100
)

# This is where all the work happens (this can take some time, for us it took ~15 minutes).
cutout.prepare(['height', 'wind', 'influx', 'temperature'])
# Out:
# INFO:atlite.cutout:Building new cutout th_1.nc
# INFO:atlite.data:Storing temporary files in /var/folders/rx/tstwq_0j2fs2k5dh4m8xnhdc0000gn/T/tmptejmar43
# INFO:atlite.data:Calculating and writing with module era5:
# INFO:atlite.datasets.era5:Requesting data for feature influx...
# INFO:atlite.datasets.era5:Requesting data for feature wind...
# INFO:atlite.datasets.era5:Requesting data for feature temperature...
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# 2024-09-12 21:55:24,956 INFO Request ID is feded440-6836-4d30-bbbf-f1acc2393ed2
# INFO:cads_api_client.processing:Request ID is feded440-6836-4d30-bbbf-f1acc2393ed2
# 2024-09-12 21:55:25,330 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-09-12 21:55:25,030 INFO Request ID is deb9e57a-1991-4337-9ea8-618c9c04a3ed
# INFO:cads_api_client.processing:Request ID is deb9e57a-1991-4337-9ea8-618c9c04a3ed
# 2024-09-12 21:55:25,030 INFO Request ID is 41fa12c3-d2ef-40c4-a52a-a369e3116b3f
# INFO:cads_api_client.processing:Request ID is 41fa12c3-d2ef-40c4-a52a-a369e3116b3f
# 2024-09-12 21:55:25,347 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-09-12 21:55:25,352 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted

# %%
cutout.data
# Out:
# <xarray.Dataset> Size: 11MB
# Dimensions:               (x: 100, y: 82, time: 24)
# Coordinates:
#   * x                     (x) float64 800B 97.36 97.37 97.38 ... 98.34 98.35
#   * y                     (y) float64 656B 10.63 10.64 10.65 ... 11.43 11.44
#   * time                  (time) datetime64[ns] 192B 2011-01-01 ... 2011-01-0...
#     lon                   (x) float64 800B dask.array<chunksize=(100,), meta=np.ndarray>
#     lat                   (y) float64 656B dask.array<chunksize=(82,), meta=np.ndarray>
# Data variables: (12/13)
#     height                (y, x) float32 33kB dask.array<chunksize=(82, 100), meta=np.ndarray>
#     wnd100m               (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     wnd_azimuth           (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     roughness             (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     influx_toa            (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     influx_direct         (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     ...                    ...
#     albedo                (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     solar_altitude        (time, y, x) float64 2MB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     solar_azimuth         (time, y, x) float64 2MB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     temperature           (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     soil temperature      (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
#     dewpoint temperature  (time, y, x) float32 787kB dask.array<chunksize=(24, 82, 100), meta=np.ndarray>
# Attributes:
#     module:                  era5
#     prepared_features:       ['wind', 'height', 'temperature', 'influx']
#     chunksize_time:          100
#     dx:                      0.01
#     dy:                      0.01
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-08-29T01:41 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
cap_factors = cutout.wind(turbine="Vestas_V112_3MW", capacity_factor=True)
# Out:
# INFO:atlite.convert:Convert and aggregate 'wind'.

# %%
cap_factors.plot()

# %%
sites = gpd.GeoDataFrame(
    [
        ["P1", 11, 97.8],
        ["P2", 10.5, 98],
        ["P3", 11.2, 97.5],
    ],
    columns=["name", "x", "y"],
).set_index("name")

cells = cutout.grid
nearest = cutout.data.sel({"x": sites.x.values, "y": sites.y.values}, "nearest").coords
sites["x"] = nearest.get("x").values
sites["y"] = nearest.get("y").values
cells_generation = sites.merge(cells, how="inner").rename(pd.Series(sites.index))
print(cells_generation)

power_generation = cutout.pv(    
        panel="CSi",
        orientation="latitude_optimal",
        capacity_factor=True,
        tracking= None,
        shapes=cells_generation.geometry
)
fig, axes = plt.subplots(len(sites), sharex=True, figsize=(9, 4))


power_generation.to_pandas().plot(subplots=True, ax=axes)
print(power_generation.to_pandas())
fig.tight_layout()
# Out:
# INFO:atlite.convert:Convert and aggregate 'pv'.
#         x      y                                           geometry
# P1  97.36  11.44  POLYGON ((97.365 11.435, 97.365 11.445, 97.355...
# P2  97.36  11.44  POLYGON ((97.365 11.435, 97.365 11.445, 97.355...
# P3  97.36  11.44  POLYGON ((97.365 11.435, 97.365 11.445, 97.355...
# dim_0                      P1        P2        P3
# time
# 2011-01-01 00:00:00  0.000000  0.000000  0.000000
# 2011-01-01 01:00:00  0.026771  0.026771  0.026771
# 2011-01-01 02:00:00  0.186366  0.186366  0.186366
# 2011-01-01 03:00:00  0.379576  0.379576  0.379576
# 2011-01-01 04:00:00  0.515211  0.515211  0.515211
# 2011-01-01 05:00:00  0.580106  0.580106  0.580106
# 2011-01-01 06:00:00  0.607022  0.607022  0.607022
# 2011-01-01 07:00:00  0.550769  0.550769  0.550769
# 2011-01-01 08:00:00  0.481684  0.481684  0.481684
# 2011-01-01 09:00:00  0.433158  0.433158  0.433158
# 2011-01-01 10:00:00  0.274724  0.274724  0.274724
# 2011-01-01 11:00:00  0.099210  0.099210  0.099210
# 2011-01-01 12:00:00  0.000000  0.000000  0.000000
# 2011-01-01 13:00:00  0.000000  0.000000  0.000000
# 2011-01-01 14:00:00  0.000000  0.000000  0.000000
# 2011-01-01 15:00:00  0.000000  0.000000  0.000000
# 2011-01-01 16:00:00  0.000000  0.000000  0.000000
# 2011-01-01 17:00:00  0.000000  0.000000  0.000000
# 2011-01-01 18:00:00  0.000000  0.000000  0.000000
# 2011-01-01 19:00:00  0.000000  0.000000  0.000000
# 2011-01-01 20:00:00  0.000000  0.000000  0.000000
# 2011-01-01 21:00:00  0.000000  0.000000  0.000000
# 2011-01-01 22:00:00  0.000000  0.000000  0.000000
# 2011-01-01 23:00:00  0.000000  0.000000  0.000000

# %%
# area = cells_generation[:1]
area = cells_generation[:1]
print(area)
power_generation = cutout.pv(    
        panel="CSi",
        orientation="latitude_optimal",
        capacity_factor=True,
        tracking= None,
        shapes = area.geometry
)
fig, axes = plt.subplots(len(area), sharex=True, figsize=(9, 4))


power_generation.to_pandas().plot(subplots=True, ax=axes)
fig.tight_layout()
# Out:
# INFO:atlite.convert:Convert and aggregate 'pv'.
#         x      y                                           geometry
# P1  97.36  11.44  POLYGON ((97.365 11.435, 97.365 11.445, 97.355...

# %%
cutout.grid
# Out:
#           x      y                                           geometry
# 0     97.36  10.63  POLYGON ((97.365 10.625, 97.365 10.635, 97.355...
# 1     97.37  10.63  POLYGON ((97.375 10.625, 97.375 10.635, 97.365...
# 2     97.38  10.63  POLYGON ((97.385 10.625, 97.385 10.635, 97.375...
# 3     97.39  10.63  POLYGON ((97.395 10.625, 97.395 10.635, 97.385...
# 4     97.40  10.63  POLYGON ((97.405 10.625, 97.405 10.635, 97.395...
# ...     ...    ...                                                ...
# 8195  98.31  11.44  POLYGON ((98.315 11.435, 98.315 11.445, 98.305...
# 8196  98.32  11.44  POLYGON ((98.325 11.435, 98.325 11.445, 98.315...
# 8197  98.33  11.44  POLYGON ((98.335 11.435, 98.335 11.445, 98.325...
# 8198  98.34  11.44  POLYGON ((98.345 11.435, 98.345 11.445, 98.335...
# 8199  98.35  11.44  POLYGON ((98.355 11.435, 98.355 11.445, 98.345...
#
# [8200 rows x 3 columns]
