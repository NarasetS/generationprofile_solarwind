# %%
import cdsapi
import atlite

# %%
# c = cdsapi.Client()

# c.retrieve(
#     'reanalysis-era5-land',
#     {
#         'variable': [
#             '2m_temperature', 'surface_net_solar_radiation',
#         ],
#         'year': '2022',
#         'month': '01',
#         'day': '01',
#         'time': [
#             '00:00', '01:00', '02:00',
#             '03:00', '04:00', '05:00',
#             '06:00', '07:00', '08:00',
#             '09:00', '10:00', '11:00',
#             '12:00', '13:00', '14:00',
#             '15:00', '16:00', '17:00',
#             '18:00', '19:00', '20:00',
#             '21:00', '22:00', '23:00',
#         ],
#         'area': [
#             90, -180, -90,
#             180,
#         ],
#         'format': 'netcdf',
#     },
#     'download.nc')

# %%
# cutout = atlite.Cutout(
#     path="download.nc",
#     module="era5",
#     x=slice(-13.6913, -10.7712),
#     y=slice(49.9096, 52.8479),
#     dx = 0.05,
#     dy = 0.05,
#     time="2022-01-01",
# )

# cutout.prepare()

# cutout.data

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
import geopandas as gpd
import pandas as pd
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

import cartopy.crs as ccrs
from cartopy.crs import PlateCarree as plate
import cartopy.io.shapereader as shpreader

import xarray as xr
import atlite

import logging
import warnings

warnings.simplefilter("ignore")
logging.captureWarnings(False)
logging.basicConfig(level=logging.INFO)

# %%
# import cdsapi

# dataset = "reanalysis-era5-land"
# request = {
#     'variable': ['surface_net_solar_radiation'],
#     'year': '2015',
#     'month': '01',
#     'day': ['01'],
#     'time': ['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00'],
#     'data_format': 'netcdf',
#     'download_format': 'unarchived',
#     'area': [90, -180, -90, 180]
# }

# client = cdsapi.Client()
# client.retrieve(dataset, request).download()

# %%
shpfilename = shpreader.natural_earth(
    resolution="10m", category="cultural", name="admin_0_countries"
)
reader = shpreader.Reader(shpfilename)
UkIr = gpd.GeoSeries(
    {r.attributes["NAME_EN"]: r.geometry for r in reader.records()},
    crs={"init": "epsg:4326"},
).reindex(["Thailand"])

# %%
UkIr.unary_union.bounds
# Out:
# (97.35140100100011, 5.629890035000059, 105.65099776200003, 20.44500640900013)

# %%
# Define the cutout; this will not yet trigger any major operations
cutout = atlite.Cutout(
    path="th-2011-01-01", module="era5", bounds= (97.35140100100011, 10.629890035000059, 98.35140100100011, 11.44500640900013)  , time="2011-01-01", dx= 0.25 , dy = 0.25
)

# This is where all the work happens (this can take some time, for us it took ~15 minutes).
cutout.prepare(['height', 'wind', 'influx', 'temperature'])
# Out:
# INFO:atlite.cutout:Building new cutout th-2011-01-01.nc
# INFO:atlite.data:Storing temporary files in C:\Users\EGAT\AppData\Local\Temp\tmpibasu6wb
# INFO:atlite.data:Calculating and writing with module era5:
# INFO:atlite.datasets.era5:Requesting data for feature height...
# INFO:atlite.datasets.era5:Requesting data for feature wind...
# INFO:atlite.datasets.era5:Requesting data for feature influx...
# INFO:atlite.datasets.era5:Requesting data for feature temperature...
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# 2024-08-28 14:15:14,965 INFO Request ID is 4d1426a9-9ac4-4832-9b82-d51715ed1305
# INFO:cads_api_client.processing:Request ID is 4d1426a9-9ac4-4832-9b82-d51715ed1305
# 2024-08-28 14:15:14,968 INFO Request ID is 362d0bb5-17cf-46cf-aeda-95012325fecb
# INFO:cads_api_client.processing:Request ID is 362d0bb5-17cf-46cf-aeda-95012325fecb
# 2024-08-28 14:15:14,975 INFO Request ID is 64898c2f-41c6-429e-b743-d4f77220af5b
# INFO:cads_api_client.processing:Request ID is 64898c2f-41c6-429e-b743-d4f77220af5b
# 2024-08-28 14:15:14,992 INFO Request ID is 1b3edafd-8a7e-4998-89c9-6ed302310770
# INFO:cads_api_client.processing:Request ID is 1b3edafd-8a7e-4998-89c9-6ed302310770
# 2024-08-28 14:15:15,258 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-28 14:15:15,261 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-28 14:15:15,265 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-28 14:15:15,287 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-28 14:36:13,452 INFO Creating download object as as_source with files:
# ['data_stream-oper.nc']
# INFO:cads_api_client.processing:Creating download object as as_source with files:
# ['data_stream-oper.nc']
# 2024-08-28 14:36:13,455 INFO Creating download object as as_source with files:
# ['data_stream-oper.nc']
# INFO:cads_api_client.processing:Creating download object as as_source with files:
# ['data_stream-oper.nc']
# 2024-08-28 14:36:13,455 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2024-08-28 14:36:13,459 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-08-28 14:36:13,480 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2024-08-28 14:36:13,486 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	geopotential (2011-1)
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/48afed4c57eee4c9adfbf49091eaa0a6.nc
# 2024-08-28 14:38:17,321 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-08-28 14:38:17,323 INFO Creating download object as as_source with files:
# ['data_stream-oper.nc']
# INFO:cads_api_client.processing:Creating download object as as_source with files:
# ['data_stream-oper.nc']
# 2024-08-28 14:38:17,325 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-08-28 14:38:17,344 INFO Creating download object as as_source with files:
# ['data_stream-oper.nc']
# INFO:cads_api_client.processing:Creating download object as as_source with files:
# ['data_stream-oper.nc']
# 2024-08-28 14:38:17,345 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	100m_u_component_of_wind (2011-[1])
# 	100m_v_component_of_wind (2011-[1])
# 	forecast_surface_roughness (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/58c3f2f32e4f0bfc9827ab5687d292f7.nc
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	surface_net_solar_radiation (2011-[1])
# 	surface_solar_radiation_downwards (2011-[1])
# 	toa_incident_solar_radiation (2011-[1])
# 	total_sky_direct_solar_radiation_at_surface (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/9dc138f6e393f05f3c8d942d53397d21.nc
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	2m_temperature (2011-[1])
# 	soil_temperature_level_4 (2011-[1])
# 	2m_dewpoint_temperature (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/def005e624146b89980d03926d56ab56.nc
# <Cutout "th-2011-01-01">
#  x = 97.40 ⟷ 98.30, dx = 0.10
#  y = 10.70 ⟷ 11.40, dy = 0.10
#  time = 2011-01-01 ⟷ 2011-01-01, dt = h
#  module = era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature']

# %%
cutout.data
# Out:
# <xarray.Dataset> Size: 108kB
# Dimensions:               (x: 10, y: 8, time: 24)
# Coordinates:
#   * x                     (x) float64 80B 97.4 97.5 97.6 97.7 ... 98.1 98.2 98.3
#   * y                     (y) float64 64B 10.7 10.8 10.9 11.0 ... 11.2 11.3 11.4
#   * time                  (time) datetime64[ns] 192B 2011-01-01 ... 2011-01-0...
#     lon                   (x) float64 80B dask.array<chunksize=(10,), meta=np.ndarray>
#     lat                   (y) float64 64B dask.array<chunksize=(8,), meta=np.ndarray>
# Data variables: (12/13)
#     height                (y, x) float32 320B dask.array<chunksize=(8, 10), meta=np.ndarray>
#     wnd100m               (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     wnd_azimuth           (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     roughness             (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     influx_toa            (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     influx_direct         (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     ...                    ...
#     albedo                (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     solar_altitude        (time, y, x) float64 15kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     solar_azimuth         (time, y, x) float64 15kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     temperature           (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     soil temperature      (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
#     dewpoint temperature  (time, y, x) float32 8kB dask.array<chunksize=(24, 8, 10), meta=np.ndarray>
# Attributes:
#     module:                  era5
#     prepared_features:       ['influx', 'height', 'temperature', 'wind']
#     chunksize_time:          100
#     dx:                      0.1
#     dy:                      0.1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-08-28T07:36 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
cap_factors = cutout.wind(turbine="Vestas_V112_3MW", capacity_factor=True)
# Out:
# INFO:atlite.convert:Convert and aggregate 'wind'.

# %%
cap_factors.plot()
