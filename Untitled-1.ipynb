# %%
import cdsapi
import atlite

# %%
# c = cdsapi.Client()

# c.retrieve(
#     'reanalysis-era5-land',
#     {
#         'variable': [
#             '2m_temperature', 'surface_net_solar_radiation',
#         ],
#         'year': '2022',
#         'month': '01',
#         'day': '01',
#         'time': [
#             '00:00', '01:00', '02:00',
#             '03:00', '04:00', '05:00',
#             '06:00', '07:00', '08:00',
#             '09:00', '10:00', '11:00',
#             '12:00', '13:00', '14:00',
#             '15:00', '16:00', '17:00',
#             '18:00', '19:00', '20:00',
#             '21:00', '22:00', '23:00',
#         ],
#         'area': [
#             90, -180, -90,
#             180,
#         ],
#         'format': 'netcdf',
#     },
#     'download.nc')

# %%
# cutout = atlite.Cutout(
#     path="download.nc",
#     module="era5",
#     x=slice(-13.6913, -10.7712),
#     y=slice(49.9096, 52.8479),
#     dx = 0.05,
#     dy = 0.05,
#     time="2022-01-01",
# )

# cutout.prepare()

# cutout.data

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
import geopandas as gpd
import pandas as pd
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

import cartopy.crs as ccrs
from cartopy.crs import PlateCarree as plate
import cartopy.io.shapereader as shpreader

import xarray as xr
import atlite

import logging
import warnings

warnings.simplefilter("ignore")
logging.captureWarnings(False)
logging.basicConfig(level=logging.INFO)

# %%
# import cdsapi

# dataset = "reanalysis-era5-land"
# request = {
#     'variable': ['surface_net_solar_radiation'],
#     'year': '2015',
#     'month': '01',
#     'day': ['01'],
#     'time': ['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00'],
#     'data_format': 'netcdf',
#     'download_format': 'unarchived',
#     'area': [90, -180, -90, 180]
# }

# client = cdsapi.Client()
# client.retrieve(dataset, request).download()

# %%
shpfilename = shpreader.natural_earth(
    resolution="10m", category="cultural", name="admin_0_countries"
)
reader = shpreader.Reader(shpfilename)
UkIr = gpd.GeoSeries(
    {r.attributes["NAME_EN"]: r.geometry for r in reader.records()},
    crs={"init": "epsg:4326"},
).reindex(["Thailand"])

# %%
UkIr.unary_union.bounds
# Out:
# (97.35140100100011, 5.629890035000059, 105.65099776200003, 20.44500640900013)

# %%
# Define the cutout; this will not yet trigger any major operations
cutout = atlite.Cutout(
    path="th-2011-01-01", module="era5", bounds= (97.35140100100011, 10.629890035000059, 98.35140100100011, 11.44500640900013)  , time="2011-01-01", dx= 0.05 , dy = 0.05
)

# This is where all the work happens (this can take some time, for us it took ~15 minutes).
cutout.prepare(['height', 'wind', 'influx', 'temperature'])
# Out:
# INFO:atlite.cutout:Building new cutout th-2011-01-01.nc
# INFO:atlite.data:Storing temporary files in C:\Users\EGAT\AppData\Local\Temp\tmpn2xu2o0y
# INFO:atlite.data:Calculating and writing with module era5:
# INFO:atlite.datasets.era5:Requesting data for feature height...
# INFO:atlite.datasets.era5:Requesting data for feature wind...
# INFO:atlite.datasets.era5:Requesting data for feature temperature...
# INFO:atlite.datasets.era5:Requesting data for feature influx...
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# Done_loading
# 2024-08-29 08:42:55,976 INFO Request ID is 237e7356-5b97-4774-a85b-801700f80cc9
# INFO:cads_api_client.processing:Request ID is 237e7356-5b97-4774-a85b-801700f80cc9
# 2024-08-29 08:42:55,982 INFO Request ID is d7b22c77-e089-434a-afb1-92bea27665fc
# INFO:cads_api_client.processing:Request ID is d7b22c77-e089-434a-afb1-92bea27665fc
# 2024-08-29 08:42:55,983 INFO Request ID is 0a955063-674a-49bc-bd56-59e6da140c64
# INFO:cads_api_client.processing:Request ID is 0a955063-674a-49bc-bd56-59e6da140c64
# 2024-08-29 08:42:55,998 INFO Request ID is c0d2af55-5b52-4772-aa25-4434875609e4
# INFO:cads_api_client.processing:Request ID is c0d2af55-5b52-4772-aa25-4434875609e4
# 2024-08-29 08:42:56,275 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-29 08:42:56,278 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-29 08:42:56,283 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-29 08:42:56,302 INFO status has been updated to accepted
# INFO:cads_api_client.processing:status has been updated to accepted
# 2024-08-29 08:43:46,674 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2024-08-29 08:43:46,675 INFO Creating download object as as_source with files:
# ['data_stream-oper.nc']
# 2024-08-29 08:43:46,676 INFO Creating download object as as_source with files:
# ['data_stream-oper.nc']
# INFO:cads_api_client.processing:Creating download object as as_source with files:
# ['data_stream-oper.nc']
# INFO:cads_api_client.processing:Creating download object as as_source with files:
# ['data_stream-oper.nc']
# 2024-08-29 08:43:46,681 INFO status has been updated to running
# 2024-08-29 08:43:46,685 INFO status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# INFO:cads_api_client.processing:status has been updated to running
# 2024-08-29 08:43:46,710 INFO Creating download object as as_source with files:
# ['data_stream-oper.nc']
# INFO:cads_api_client.processing:Creating download object as as_source with files:
# ['data_stream-oper.nc']
# 2024-08-29 08:43:46,711 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	geopotential (2011-1)
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/31b24c9f5b5309d890b9699d3a483249.nc
# 2024-08-29 08:44:12,606 INFO Creating download object as as_source with files:
# ['data_stream-oper.nc']
# INFO:cads_api_client.processing:Creating download object as as_source with files:
# ['data_stream-oper.nc']
# 2024-08-29 08:44:12,607 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-08-29 08:44:12,610 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# 2024-08-29 08:44:12,625 INFO status has been updated to successful
# INFO:cads_api_client.processing:status has been updated to successful
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	surface_net_solar_radiation (2011-[1])
# 	surface_solar_radiation_downwards (2011-[1])
# 	toa_incident_solar_radiation (2011-[1])
# 	total_sky_direct_solar_radiation_at_surface (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/8151fb40fd1c042c17d14711cc9338b4.nc
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	100m_u_component_of_wind (2011-[1])
# 	100m_v_component_of_wind (2011-[1])
# 	forecast_surface_roughness (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/9d9df9cd090cb7ad2802a5eee1b2aa3e.nc
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	2m_temperature (2011-[1])
# 	soil_temperature_level_4 (2011-[1])
# 	2m_dewpoint_temperature (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache/a2de5f27bae4ba0a29e36df25a820bcd.nc
# <Cutout "th-2011-01-01">
#  x = 97.40 ⟷ 98.35, dx = 0.05
#  y = 10.65 ⟷ 11.40, dy = 0.05
#  time = 2011-01-01 ⟷ 2011-01-01, dt = h
#  module = era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature']

# %%
cutout.data
# Out:
# <xarray.Dataset> Size: 432kB
# Dimensions:               (x: 20, y: 16, time: 24)
# Coordinates:
#   * x                     (x) float64 160B 97.4 97.45 97.5 ... 98.25 98.3 98.35
#   * y                     (y) float64 128B 10.65 10.7 10.75 ... 11.3 11.35 11.4
#   * time                  (time) datetime64[ns] 192B 2011-01-01 ... 2011-01-0...
#     lon                   (x) float64 160B dask.array<chunksize=(20,), meta=np.ndarray>
#     lat                   (y) float64 128B dask.array<chunksize=(16,), meta=np.ndarray>
# Data variables: (12/13)
#     height                (y, x) float32 1kB dask.array<chunksize=(16, 20), meta=np.ndarray>
#     wnd100m               (time, y, x) float32 31kB dask.array<chunksize=(24, 16, 20), meta=np.ndarray>
#     wnd_azimuth           (time, y, x) float32 31kB dask.array<chunksize=(24, 16, 20), meta=np.ndarray>
#     roughness             (time, y, x) float32 31kB dask.array<chunksize=(24, 16, 20), meta=np.ndarray>
#     influx_toa            (time, y, x) float32 31kB dask.array<chunksize=(24, 16, 20), meta=np.ndarray>
#     influx_direct         (time, y, x) float32 31kB dask.array<chunksize=(24, 16, 20), meta=np.ndarray>
#     ...                    ...
#     albedo                (time, y, x) float32 31kB dask.array<chunksize=(24, 16, 20), meta=np.ndarray>
#     solar_altitude        (time, y, x) float64 61kB dask.array<chunksize=(24, 16, 20), meta=np.ndarray>
#     solar_azimuth         (time, y, x) float64 61kB dask.array<chunksize=(24, 16, 20), meta=np.ndarray>
#     temperature           (time, y, x) float32 31kB dask.array<chunksize=(24, 8, 20), meta=np.ndarray>
#     soil temperature      (time, y, x) float32 31kB dask.array<chunksize=(24, 8, 20), meta=np.ndarray>
#     dewpoint temperature  (time, y, x) float32 31kB dask.array<chunksize=(24, 8, 20), meta=np.ndarray>
# Attributes:
#     module:                  era5
#     prepared_features:       ['temperature', 'height', 'influx', 'wind']
#     chunksize_time:          100
#     dx:                      0.05
#     dy:                      0.05
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-08-29T01:43 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
cap_factors = cutout.wind(turbine="Vestas_V112_3MW", capacity_factor=True)
# Out:
# INFO:atlite.convert:Convert and aggregate 'wind'.

# %%
cap_factors.plot()
